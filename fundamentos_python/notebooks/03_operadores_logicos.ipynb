# %%
cantidad = 20

# %%
cantidad > 0 # mayor que >
# Out:
# True

# %%
cantidad >= 20 # mayor igual que >=
# Out:
# True

# %%
cantidad <= 10 # menor igual que <=
# Out:
# False

# %%
cantidad < 0 # menor que <
# Out:
# False

# %%
ciudad_1 = "Arequipa"
ciudad_2 = "Lima"

ciudad_1 == ciudad_2 # igualdad ==
# Out:
# False

# %%
ciudad_1 == "Arequipa"
# Out:
# True

# %%
ciudad_1 != "Arequipa" # diferente a !=
# Out:
# False

# %%
ciudad_2 != "Arquipa"
# Out:
# True

# %%
cantidad = 20
precio = 10

cantidad > 5 and precio > 10 # Y ambas condiciones que tienen que cumplir para que sea verdadero > and
# Out:
# False

# %%
cantidad > 5 or precio > 10 # O una de las condciones se debe cumplir para que sea verdadero > or
