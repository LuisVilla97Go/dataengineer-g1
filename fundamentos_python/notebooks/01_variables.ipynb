# %%
# TIPO DE VARIABLES

# %%
cantidad: int = 3 # int
precio: float = 145.0 # float
cliente: str = "Marco Torres" # str
activo: bool = True # bool
descuento: None = None # valor nulo

# %%
print("Tipo de la variable cantidad:", type(cantidad))
print("Tipo de la variable precio:",type(precio))
print("Tipo de la variable descuento:",type(descuento))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'NoneType'>

# %%
# CASTEO DE VARIABLES

# %%
cantidad = "3"
print(type(cantidad))

cantidad = int(cantidad)
print(type(cantidad))
# Out:
# <class 'str'>
# <class 'int'>

# %%
precio = "130.5"
print(type(precio))

precio = float(precio)
print(type(precio))
print(precio)

precio = int(precio)
print(precio)
# Out:
# <class 'str'>
# <class 'float'>
# 130.5
# 130

# %%
activo = 0
print(activo)
activo = bool(activo)
print(activo)
# Out:
# 0
# False

# %%
activo = -1000
print(activo)

activo = bool(activo)
print(activo)
# Out:
# -1000
# True

# %%
precio = "3.5"
precio = int((precio))

print(precio)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 precio = "3.5"
# ----> 2 precio = int((precio))
#       3
#       4 print(precio)
#
# ValueError: invalid literal for int() with base 10: '3.5'
